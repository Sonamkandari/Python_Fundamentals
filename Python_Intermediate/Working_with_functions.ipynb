# %%
# Modular programming in python
 # Functions 
    # what is a function ?
    # def Statement
    # Function arguments
    # Lambda Functions
# Object Oriented Programming
    # Objects
    # Class
    # Attributes
    # Methods
    # Instance Vs Class vs Static

# Modular programming in python
