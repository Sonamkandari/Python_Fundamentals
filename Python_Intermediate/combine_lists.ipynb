# %%
# How to combine ?
# Different products , orders and customers
letters = ['a','b','c']
numbers = [1,2,3,4]
comb = letters + numbers
print(comb)

# Multiplier Operator : Makes multiple copies of the same list
print(letters*2) # the characters will get printed by twice

numbers.extend(letters)
print(letters)
print(numbers) # after the number list it will be followed by the characters list

# Combining using zip()
schools = ['A','B','C','D']
Classes = ['1','2','3','4']
# comb = zip(letters, numbers)
# print(comb)  # iterator object (zip object)

comb = list(zip(letters, numbers))
print(comb)
# python stops with the shortest list

# You can pair List with String value
# Task Pair Customers with their IDs (rebuild the relationships)
id = [101, 102 , 103]
names = ['Ali', 'Sara', 'John']
# print(id + names)
# We are building relationships between two different lists
print(list(zip(id,names)))
# Out:
# ['a', 'b', 'c', 1, 2, 3, 4]
# ['a', 'b', 'c', 'a', 'b', 'c']
# ['a', 'b', 'c']
# [1, 2, 3, 4, 'a', 'b', 'c']
# [('a', 1), ('b', 2), ('c', 3)]
# [(101, 'Ali'), (102, 'Sara'), (103, 'John')]
