# %%
# Data Structure: It is a way of organizing and storing data so it can be used efficiently. 
# We have four types of built-in data structures:
# - list[]
# - tuple()
# - set{}
# - dictionaries -> dict{}

# List = ['a','b','c' ]
# ordered collection of items
# Changeable
# Allows Duplicate
# List are very common and widely used data structure in python

# How to create List
# How to access and read our data
# How to unpack your data
# How to explore and Analyze your data
# How to change data?
# How to Order and organize data
# How to copy data
# How to combine ?

# Advance Topic
# How to iterate data ?
# How to transform ?
# How to filter data ?
# List Comprehensions
