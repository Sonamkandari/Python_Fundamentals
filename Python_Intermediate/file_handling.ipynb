# %%
# Reading a file
file = open("student.txt","r")
print(file.read())
print(file.readline())

file = open("student.txt","w")
file.write("\nI am from Dehradun")
file.close()

file = open ("student.txt","r")
print(file.read())
file.close()
#Closing a file releases the associated system resources and ensures buffered data is written to disk.


# use with 
with open ("student.txt") as file:
    print(file.rea())

# with automatically closes the file, even if an exception occurs
# Closing a file releases the associated system resources and ensures buffered data is written to disk.

# Q1. Why use with open()?

# -> Because it automatically manages the file resource and guarantees the file is closed properly.
# Out:
# I am from Dehradun
#
#
# I am from Dehradun

# %%
file = open("student.txt","r")
print(file.read())
print(file.readline())

file = open("student.txt","a")
file.write("\nHellow world")

file = open("student.txt","a")
file.write("\nMy name is ")
file = open("student.txt", "a+")
file.seek(0)
print(file.readlines())
file.close()
# Out:
# I am from Dehradun
# I am from Dehradun
# Hellow world
# My name is
# Hellow world
# My name is
#
# ['\n', 'I am from Dehradun\n', 'I am from Dehradun\n', 'Hellow world\n', 'My name is \n', 'Hellow world\n', 'My name is \n', 'Hellow world\n', 'My name is ']
