# %%
# import the math module
import math
math.pow(2,2)

# A module is a collection of functions and variables that have been bundled together in a single file.
# Modules help us use for code organization, packaging, and reusability. A module is a Python file, 
# a package is a folder with an __init__.py file, and the namespace is based on the file directory path.

# %%
# There are a lot of highly used packages in Python.
#  Some of them are given below. 
# NumPy, 
# Pandas,
# Matplotlib,
# Seaborn
# Scikit-Learn
# Requests,
# Urllib3
# NLTK 

# These are the works of someone else, and you can directly use these works.
#  Also, you can create your own packages and upload them so that you can also
#  use them, and other people can use them.

# %%
# Exception Handling 
# Exception is something that happens when you are running the code. 
# We can say "exception" is an unusual condition that can occur. 
#   Example of this
print("sonam welcome to shanti")
try:
    1/0  # --> this will throw the error
except ZeroDivisionError:
    print('exception occured')

print("thaNKYOU Now let's go")
# Out:
# sonam welcome to shanti
# exception occured
# thaNKYOU Now let's go

# %%
try:
    x=1/0
except ZeroDivisionError:
    print('divided by zero')
    print('executed when exception occurs')  

# We have different types of exceptions in Python, like:
- AttributeError\
- EOFError
- IOError
- IndexError 
- KeyError
- KeyboardInterrupt
- NameError
- StopIteration
- TypeError
- ValueError
- ZeroDivisionError
#These are some different kinds of errors which we can find in Python.
# Out:
# divided by zero
# executed when exception occurs
