# %%
# How to iterate
# all data is stored in the memory

# ITERATOR
# iterator will not store everything in the memory , It is not like a container or a box
# It is more like a machine that is going to produce values. 
# It is going to produce values one by one as long as you are going to ask from it

# why do we need iterators
# Mainly it has three reasons
# -> we needed it in order to build an loop (for forloop we always need an iterator)
# -> we used it in order save the memory (If we have a lot of data, we don't want to
#  use it all inside the memory. ) Place of that, we're going to use iterator. Trader 
# will stream the data one by one, and it is like gold for big data. 
# -> The third reason is speed and flexibility. 

letters = ['a','b','c']
# creating a new_list to store transformed data
new_list = []
for l in letters:
    # we use iteration to transform data
    new_list.append(l.upper()) # How to transform
    #print(l.upper()) # all the characters will be in the upper case now
    print(new_list)
#we use iteration to transform data

# Iterators enumerate reversed zip
# when we use enumerators it gonna return two things 1 - index and 2. is value

print()
values = ['1','2','6','7']
# print (list(enumerate(values)))   # it help to return the values with its index


# we use enumerator with for loop
for index, value in enumerate(values):
    print(index,value)

# Enumerate Use case'
# -> Find the exact position of the bad data in your list

# Reversed: Returns an iterator that flips the data order
print(list(reversed(values))) # the list will be printed in the reversed order

for l in reversed(letters):
    print(l)    
# How to filter

# Store the transformed results in a new list
# Zip : Combines two or more sequences into pairs (tuples)

# covert letters of the string into upper case letters
letters = ['a','b','c']
print(list(map(str.upper,letters)))

# convert the list items to integers
numbers = ['1','7','9','5']
print(list(map(int,numbers)))

# clean up the list by removing all unwanted spaces
names = [' Maria','Johan','Kumar']
print(list(map(str.strip,names)))

# Note map is fast, clean way to do data transformation


# Iterator filter
# Clean up the list by removing invalid data
data = ['k',' ','k',False,'j',12 ]
# build or create a filter to clean the above list
# removes all falsy values like ), ", or False
print(list(filter(None,letters)))

# Note : Filter() is perfect for cleaning up data in your structures
# Out:
# ['A']
# ['A', 'B']
# ['A', 'B', 'C']
#
# 0 1
# 1 2
# 2 6
# 3 7
# ['7', '6', '2', '1']
# c
# b
# a
# ['A', 'B', 'C']
# [1, 7, 9, 5]
# ['Maria', 'Johan', 'Kumar']
# ['a', 'b', 'c']
