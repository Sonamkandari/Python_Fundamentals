# %%
#  write now we will work on only basic file system  that is .txt files but in future we may work on different files system
with open('data.txt','w') as f:
    f.write("this is my first code of working with files using pythons:\n")
    f.write("second line:Yellow Moon: \n")
    f.write("Third line:Blue Moon:\n")
    f.write("last Line:Red Moon:\n")
    # we just added the new data in the file

# %%
# we can also read data from file by line by line
with open("data.txt",'r') as f:
    for line in f:
        print(line)
# Out:
# this is my first code of working with files using pythons:
#
# second line:Yellow Moon:
#
# Third line:Blue Moon:
#
# last Line:Red Moon:
