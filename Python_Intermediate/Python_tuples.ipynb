# %%
# In total we have four types of data structures
# -> List [1,2]
# -> Tuple (1,2)
# -> Set {1,2}
# -> dictionary {a:1, b:2}

# Data Structures
# -> Ordered 
# -> Duplicates
# -> Indexed
# -> Mutable
