# %%
# Variable Assignment
print("info@datawithsonam.com")
print("support@datawithsonam.com")
print("www.datawithsonam.com")

#let use variables here 
domain="com"
source="WWW"

print("info@datawithsonam.",domain)
print("support@datawithsonam.",domain)
print(source,".datawithsonam.",domain)
# Out:
# info@datawithsonam.com
# support@datawithsonam.com
# www.datawithsonam.com
# info@datawithsonam. com
# support@datawithsonam. com
# WWW .datawithsonam. com
