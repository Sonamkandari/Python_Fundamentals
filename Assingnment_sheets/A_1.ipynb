# %%
# Validate the quality and correctness of email values. 
#Email must not be empty.
# Email must contain "." and "@" symbol 
# Email must contain exactly one @ symbol. 
# E-mail must end with.com,.org, or.net. 
# Must not be longer than 254 characters. 
# Must start and end with a letter or digit. 


email = "  sonam@gmail.com "
domains = [".com",".org",".net"]

# clean the string 
email = email.strip()

# email must not be empty
if email == " ":
    print("Email cannot be Empty")

# Must start and end with a letter or digit 
elif not(email[0].isalnum() and email[-1].isalnum()):
    print("Must start and end with a letter or digit ") 

# Email must contain "." and "@" symbol 
elif not('@' in email and "." in email):
    print("Email must contain . and @ ")

# Email must contain exactly one @ symbol.  
elif not(email.count("@")==1):
    print("one @ only")

# Must not be longer than 254 characters.  
elif not (len(email)<254):
    print("length of email should not greater than 257")

else:
    print("It is a valid email")
# Out:
# It is a valid email

# %%
# Print the 7-times table from 1 to 10 using loop
for i in range (1,11):
    print(f"7 x {i} = {7*i}")

print()

# print a left- aligned pyramid of stars with 6 rows using a for loop
for i in range (1,7):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
# *
# **
# ***
# ****
# *****
# ******
