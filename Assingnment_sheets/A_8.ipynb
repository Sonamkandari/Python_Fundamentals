# %%
number = "+49 (176) 123-4567"
print(number.replace("+","00" )
      .replace("(","")
      .replace(")","")
      .replace("-","",)  
      .replace(" ","")        
            
                                      ,"","-",""," ",""))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 number = "+49 (176) 123-4567"
# ----> 2 print(number.replace("+","00" |"(",""|")",""|"-",""|" ",""))
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
