# %%
# sleep() → Normal method
# sound() → Abstract method

# This is an Abstract Class.

# -> But  for interface

# sleep() →  Abstract method
# sound() → Abstract method

# Every method is abstract.
# There are no implemented methods.
# This ABC is being used as an Interface.

# | Feature                       | Abstract Class | Interface (Concept) |
# | ----------------------------- | -------------- | ------------------- |
# | Can have normal methods       | ✅ Yes          | ❌ Ideally no     |
# | Can have abstract methods     | ✅ Yes          | ✅ Yes            |
# | Can share implementation      | ✅ Yes          | ❌ No(conceptually)|
# | Provides common functionality | ✅ Yes          | ❌ No             |
# | Defines a contract            | ✅ Yes          | ✅ Yes            |
