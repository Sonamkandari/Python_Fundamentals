# %%
# Can we store numbers inside variables?
# Yes
x = 13

# Can we store strings ?
name = "sonam" # Yes

# Can we store List in Variables

name = [1,2,3,4] # Yes

# can we store functions in variable yes!
# functions are first-class objects.

# Note: In python, functions are first-class objects, meaning they can be assigned to variables, passed as arguments to
# other functions, returned from functions, and stored in the data structures

# -> This concept is the foundation of decorators


# A Decorator is a callable that takes another function as input,
# extends or modifies its behavior, and returns a new function without
#  modifying the original function's source code.

def decorator(func):

    def wrapper():

        print("Before")

        func()

        print("After")

    return wrapper
