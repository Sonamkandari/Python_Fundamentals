# %%
# Comparison Operators: It compares two values and returns true or false based on the result. 
print(20==20)
print(20!=67)
print(20!=20)

print("sonam"=="sonam")
if(7>9):
    print("not vaLID")
else:
    print("valid")


print(9>=7)   
print(7>=7)

# in canse of character
print("a"=="A") # false 
# since Python is case sensitive 
# so "a" and "A" are treated as different value

# chained Comparison : check multiple conditions in one line, just like in math
print(5<9<10) # it will move from left to right
print(4<3<9) #false since first part is false
print(5<8<2) # false, for true each condition should be true

# Chain comparison works like SQL, between they check if a value is between two bounds. 

# Is age between 18 and 40
age = 22
print(18 <= age <= 30)
# Out:
# True
# True
# False
# True
# valid
# True
# True
# False
# True
# False
# False
# True
