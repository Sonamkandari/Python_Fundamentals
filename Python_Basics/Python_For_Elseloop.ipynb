# %%
# Runs a block of code only if the loop finishes naturally
# Loop completed without breaks

items = [1,2,3,4,5]
for i in items:
    print(i)
print("Loop is completed")    
# Create a classical for loop


# USe else with loops when there is a break statement
# Out:
# 1
# 2
# 3
# 4
# 5
# Loop is completed

# %%
# find out if there are even number
numbers = [4,7,8,9,10,6,5,3,34,28,39]
for number in numbers:
    if number % 2 == 0:
        print(f"Even number:", number)
        
else:
    print("all the number are odd")   


# Real world Applications of Else in Loops
# SEarch and validate data

# Check for Missing Names in a List

names = ['sonam', 'tuba', None , 'Erra']
for name in names:
    if name is None:
        print("Found a missing name: ",)
        break
else:
    print("There is no missing name is found")


# Check if All Files are CSV Files
files = ['data1.csv','data2.csv','raw_data.pdf','report2.doc']
# Iterate all the files
for file in files:
    if not file.endswith('.csv'):
        print(f"file is not in csv format : ",file)
        break
# if every thing is ok    
else:
    print("All files are csv")



files = ['data1.csv','data2.csv','raw_data.csv','report2.csv']
# Iterate all the files
for file in files:
    if not file.endswith('.csv'):
        print(f"file is not in csv format : ",file)
        break
# if every thing is ok    
else:
    print("All files are csv")
# Out:
# Even number: 4
# Even number: 8
# Even number: 10
# Even number: 6
# Even number: 34
# Even number: 28
# all the number are odd
# Found a missing name:
# file is not in csv format :  raw_data.pdf
# All files are csv
