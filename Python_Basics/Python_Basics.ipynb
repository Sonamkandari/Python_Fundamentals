# %%
print("Hello Data World")
# Out:
# Hello Data World

# %%
# strings are used in python to record text information, such as name. Strings in python are actually a sequence, which basically means Python keeps track of every element in the string as a sequence. for example, Python understands the string python to be a sequence of letters in a specific order.This means we will be able to use indexing to grab particular letters'
print("darshil parmar")
# Out:
# darshil parmar

# %%
# Assign S as a String 
s="Hello world"
print(s[2])

k="Raja Ram Mohan Rai"
print(k[5])
# Out:
# l
# R

# %%
# print thr object 
print(s)
# here we lean about the some basics of strings like how string indexing works, what are variables and how we can assign a string to a variable
t="Raja Ram Mohan Roy"
print(t)
print(t[0])
print(t[7])

# String Concatenation and Repetition
# String Concatenation is a process to combine two Strings.It is done Using the + operators
s1="face"
s2="book"
s3=s1+s2
print(s3)
print(s1+" "+s2)
# Out:
# Hello world
# Raja Ram Mohan Roy
# R
# m
# facebook
# face book

# %%
# want to print the data 1o times
print("sonam "*10)

#print data 15 times 
print("sona "*15)
# Out:
# sonam sonam sonam sonam sonam sonam sonam sonam sonam sonam
# sona sona sona sona sona sona sona sona sona sona sona sona sona sona sona

# %%
# String Slicing & Indexing
# String Indexing is used to select the letter at the particular index/position
# String slicing is a process to select s subset of an entire string

Ma="four Pillers of oops"
print(Ma)
print(Ma[0]) # this is indexing as we are asking about a particular index
print(Ma[8:12]) # this is know aS Slicing
print(Ma[-5])
# Out:
# four Pillers of oops
# f
# lers

# %%
# check substrings
# print "World" from string 
# print "ste" from the string

store="Hello brother how are  you"
print("brother" in store)
print("hello" in store)
print("Hello" in store)
# Out:
# True
# False
# True

# %%
# Basics  Built-in Strings methods
memo="A lot of content is stored"
print(memo)
print(memo.upper()) # uses upper built in function
print(memo.lower())# uses lower built in function
# Out:
# A lot of content is stored
# A LOT OF CONTENT IS STORED
# a lot of content is stored
