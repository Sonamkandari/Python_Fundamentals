# %%
# conditional statement in python
# if statement in python allows us to tell the computer to perform alternative action alternative actions based on a certain set of results
# verbally, we can imagine we are telling the computer
# Hey if this case happens, perform some action
# We can then expand the idea further with elif and else statement,which allow us to tell the computer
# if, elif, else statement

a=100
b=100

if a>b:
    print("A is Greater is greater tha B")
elif b>a:
    print("B is greater than A")
else:
    print("both are Equal to Each other")

# take care of indentation and in case of some modern tools like jupyter notebook or visual studio code then already take cares of indentation we don't to correct indentation manually


d=2900;
g=800;
if d>g:
    print('D is  greater then g');
elif g>g:
    print('g is greater then D');
else:
    print('D is equal to g');
# Out:
# both are Equal to Each other
# D is  greater then g

# %%
# indentation is the part of python syntax and we have to really take care of it
# Indentation: adding spaces at the beginning of our line to show that the line belongs to a code block 
score =50
if score >= 90:
    print("Good score")
else:
    print("Average Score")
# Out:
# Average Score

# %%
# Multi conditional statement
marks = 90
if marks >= 250:
    print("Grade - A")
elif marks >=100:
    print("Grade - B")
else:
    print("Grade - C")
# Out:
# Grade - C

# %%
score =  50 
if score >= 90:
    print('A')
elif score >= 80:
    print('B')
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("F")
# Out:
# F

# %%
# Connecting Conditions
# Logical Operators
score = 90 
submitted_project = True
if score >= 90 and submitted_project:
        print("A+")
elif score >= 90:
        print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("f")
# Out:
# A+

# %%
# independent Ifs
# Complex logic = Classical-if
marks = 80
submitted_project = False
if marks >= 90:
    print ("A+")
else:
    print("Low Score")
if submitted_project:
    print("project is submitted")
else:
    print("Project is not submitted")
# Out:
# Low Score
# Project is not submitted

# %%
# else if one line and match case
# Requirement in case of Simple logic = inline-if
# in line
score = 100
print("A" if score >=90 else "F")

city = "Dehradun"
print("My city is "+city if city == "Dehradun"else "Not my city")

age = 22
print("student is eligible to give vote" if age>=18 else "not eligible to give vote")
# Out:
# A
# My city is Dehradun
# student is eligible to give vote

# %%
# Case - Match
# Evaluate a value against multiple values. Run the code of the first match.
#  Convert the full country names into 2-letter abbreviations
country = "India"
if country == "United state":
    print("US")
elif country == "India":
    print("IN")
elif country == "Germany":
    print("GM")
elif country == "Egypt":
    print("EG")
else:
    print("Unknown")

# Another simple way to write the same above code is    
# Using Match keyword similar to switch case in java
match country:
    case "United state":
        print("US")
    case "India":
        print("IN") 
    case "Germany":
        print("GM")    
    case "Egypt":
        print(EG)  
    case _:  
        print("Unknown country")
# Out:
# IN
# IN
