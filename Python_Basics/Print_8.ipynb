# %%
print("               __")
print("              /  _)")
print("       .-^^^-/  /")
print("    __/        / ")
print("   <__.|_|-|__|  ")
# Out:
#                __
#               /  _)
#        .-^^^-/  /
#     __/        /
#    <__.|_|-|__|

# %%
print("Hi \"Python\"")

# we can also do it by using single courts
print('Hi "sonam"')
print('Hi \'sonam\'')
# Backslashes are always special characters in Python. 
# for example i want to print the path of an folder
print("Path: C: \\users\\revision")

# for the space
print ("Message1")
print()
print("MEssage2")

# Another way to telling python that after a line add a new line
print("Hello Good Morning \n")
print("How are you")
# Out:
# Hi "Python"
# Hi "sonam"
# Hi 'sonam'
# Path: C: \users\revision
# Message1
#
# MEssage2
# Hello Good Morning
#
# How are you

# %%
# PRINT()
# built-in Python function 
#- display a message in the output for users
# use cases:
#- communicate
#- show results
#- debug and test
print("sonam\n\n\nKanadari")

# Assessment Exercise
print("Your LEarning Path:\n  - Python Basics\n  - Data Engineering\n  - AI")
print("Your Learning Path:\n\t-Python Basics\n\t-Data Engineering\n\t-AI")
# Out:
# sonam
#
#
# Kanadari
# Your LEarning Path:
#   - Python Basics
#   - Data Engineering
#   - AI
# Your Learning Path:
# 	-Python Basics
# 	-Data Engineering
# 	-AI
