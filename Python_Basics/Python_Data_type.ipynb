# %%
# Everything in python is an "object", including integers/floats
# Most important and types (classes)
# Single value: None,int, float,bool,str, complex
# Multiple values: list, tuple set, dict

# %%
# Python automatically detects data types. 
# Dynamic: data types can change any time in Python. Due to its dynamic nature 
# Why do we need data types? 
# To know how to operate data and also to prevent problems, we need data types.

# %%
# Categories of data types 

# NO VALUE -> none
# Single Value -> int, float, String, boolean [They always holds one value and also called primitive Types]
# Multi Values -> list, dictionaries, set, tuples [Data structures, collections and containers]

# %%
# integers |int | whole no as 3,300
# floating point |float| Numbers with a decimal point like 2.3, 4.6, 100.0. |
# strings |str| order sequence of character 
# List |order sequence of objects|
# dictionaries |Unordered key: Values pairs
# Tuples |tup|Order immutable sequence of objects (10,"hello",200.3)
# Sets |set| Unordered collection of unique objects ("A","b")
# Booleans |bool| Logical value indicating True or False

a = 10 #int
b = 3.13 # float
c = "Hello" #str
d = 'Hi' #str
e = True
f = False
g=None  # Means no value, nothing, or unknown.
# It is used to show the absence of any data. 

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>
# <class 'NoneType'>

# %%
name="sonam kandari"
print(type(name))
# Out:
# <class 'str'>

# %%
text = "h1"
number = 10

# built in function
print(text)
print(number)

# another built in function

print(type(text))  # function inside an another function
type(number)

# Another built in function that is length function
print(len(text))
# Not all function will work for all data type
# print(len(number))  # this will error
# Out:
# h1
# 10
# <class 'str'>
# 2

# %%
# Methods of data type classes

text = "sonam kandari"
number = 1234

print(text.upper())
# number.upper()
#  # this method will not work for this data type

print(number.bit_length()) # it returns the length of the number in binary
print(number.bit_count())
print(text.lower())
# Out:
# SONAM KANDARI
# 11
# 5
# sonam kandari
