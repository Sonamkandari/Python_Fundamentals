# %%
# The concept of variables
# A variable is a name you create to store a value so you can use it later in you code

# How variable works?
x = 3;
print(x)
x=9;
print(x)
y=10
print(y)
# Out:
# 3
# 9
# 10

# %%
# how can we use variables in real world projects
print("My name is sonam kandari")
print("sonam is a final year student at DIT University")
print("sonam want to become an software engineer")


# Now how can we use Variable here 
# In the above passage the name can be a dynamic part of the sentence
#  and remaining part can be static
name="soni"
language="Python"
print("My name is",name)
print(name," is a final year student at DIT University and learning",language)
print(name,"want to become an software engineer")

# Variables make updates super easy one change update Everything
name="Kandari" # we will notice that the value of name will be not change as
# Note: Python executes your code Line by Line

# VARIABLES
# variables  makes programs dynamic
# Name to store a vale
# variables are stored in memory
# variables are reusable anytime
# Updatable anytime
# Out:
# My name is sonam kandari
# sonam is a final year student at DIT University
# sonam want to become an software engineer
# My name is soni
# soni  is a final year student at DIT University and learning Python
# soni want to become an software engineer
