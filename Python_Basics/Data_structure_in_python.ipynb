# %%
# The first data structure available in Python is that is list. 
# Now before understanding about the List, we will understand the basics of data structure, what are data structures and why they are used. 
# Data structures are the ways the computer stores information inside it. 
# We want to store everything efficiently, and as we required, we want to retrieve information efficiently and with the efficient time. 
# List can be thought of the most general version of a sequence in python

# %%
# create a list // similar to array in java for me
# but key  difference in between list and arrays are
# List are Dynamic (can grow and Shrink)  where as
# arrays are fixed (can not changed after declaration)

my_list=[1,'sonam',99,'Rahul',56]
print(my_list[2])
print(my_list[1])


mylist1=[90,'Annu',89,'Ruhi',89]
print(my_list[3])
print(my_list[1])

# One more difference is that in LIST, we can store different types of data.
# For example, we can store a number and a string together.
# Whereas in arrays, we can store the same type of data in a particular array.
# For example, we are creating an array for storing the numbers, so in that  
# integer array we can only store the numbers, or if we are creating a string array,
# we can only store the string values, We cannot store integers in that particular array.

# %%
# we can perform different operation on the top of the list
my_list1=['one','two','three','Four',4,5,6]
print(my_list1)
my_list1.append(7)
print(my_list1)

# we cannot append multiple values --> Because append() is designed to add exactly ONE object to a list.
# my_list1.append(4,7,9)
my_list1.append([4,7,9])
print(my_list1)

# Slicing is used to access individual elements or a range of elements in a list
#Python supports slicing on indexable sequences. The syntax for slicing is 
# list_object[start:end:step] or
# list_object[start:end]

# start ans ends are indices (start inclusive,end exclusive ). All Slicing values are optional

# %%
# this loop will print the value from 0 to 9
for i in range (10):
    print(i)

# %%
l=list(range(10))
print(l)
k=list(range(30))
print(k)
print("alternate elements, starting at index 0",k[0::2])
print("alternate elements,starting at 1 :",k[1::3])
# can we print only even number
#print("print the number which are even in the list",k%2==0) wrong way
numbers=[1,2,4,5,6,7,89,8]
print("Even numbers are:")
for k in numbers:
    if k%2==0:
     print(k)
