# %%
# while loop :
# Repeats a block of code - over and over as long as condition is true!
# while condition

age = 18 
i = 30 # for this loop we always have to initialized i

while i > 18:
    i=i-1
     # i-- not work here
    print(i)

# three two for steps are there for implementing while loop
# Initialization
# Condition
# update

 # Build a counter from 1 to 5

i = 1
while i<=5:
    print(i)
    i=i+1

# %%
# Write a program that keeps asking "Do you agree ? until the user type "yes""
user_type = " "
while (user_type!="yes"):
    user_type = input("Do you agree ? (yes or no)")
print("thankyou")
# Out:
# thankyou
