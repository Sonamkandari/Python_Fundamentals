# %%
# Tuples in python
# Variables are used to store multiple items in a single variable. 
# A tuple is a collection which is ordered and unchangeable
# tuples are written with round brackets

thistuple=('sonam','gautam','kandari')
print(thistuple)
# Out:
# ('sonam', 'gautam', 'kandari')

# %%
# creating one more tuple
storeTuples=(3,4,'4','9','8','6','7','9')
print(storeTuples)

# create one more tuples
myStoreHouse=('mango','orange','grapes','kivi')
print(myStoreHouse)

# check can we store different types of elements in tuples
bucket=(2,4,5,7,8,'ram','sayam')
print(bucket)


# tuples items are ordered, unchangeable,and allow duplicate values
# tuples items are indexed, the first item has index[0],the second item has index[1] etc
# Out:
# (3, 4, '4', '9', '8', '6', '7', '9')
# ('mango', 'orange', 'grapes', 'kivi')
# (2, 4, 5, 7, 8, 'ram', 'sayam')
